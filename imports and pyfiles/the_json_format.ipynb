# %% [markdown]
# # JSON (JavaScript Object Notation)

# %% [markdown]
# The shortest way to descrive JSON- this is just a dictionary. THATS IT

# %% [markdown]
# JSON is an open-standard format that uses human-readable text to transmit data objects consisting of **attribute–value pairs**. It is the most common data format used for asynchronous browser/server communication.
#
# JSON files follow a very strict and simple syntax, which is fully documented at the formal [homepage of the JSON organization][1]. The following are the rules of the format:
#
# * an **object** is an unordered collection of pairs of a string (called **attribute**) and a value
# * an **array** is an ordered sequence of values
# * The **values** are limited to strings, numbers, booleans and "null", but can also nest (recursively) objects and arrays
#
# [1]: http://www.json.org/ "JSON organization"

# %% [markdown]
# > **Note:** The term JSON can refer both to a JSON-formatted string and to a file containing such string.

# %% [markdown]
# ## The `json` module

# %%
import json

# %%
with open('data/some_text_file.txt') as f:
    txt = f.read()
    print(txt)
# Out:
# This is a file!

# %%
with open('data/mcdonalds.json') as f:
    mcd = json.load(f)
type(mcd)
mcd.keys()
mcd["features"][0]["properties"]["city"]
# Out:
# 'MIAMI BEACH'

# %%
# countD = 0
# for branch in mcd["features"]:
#     if (branch['properties']['driveThru'] == 'Y'):
#         countD += 1
# print(countD)
with open('data/mcdonalds.json') as f:
    mcd = json.load(f)


out = [branch for branch in mcd['features'] if branch['properties']['driveThru'] == 'Y']

with open ('data/mc_filtered.json',"w") as f:
    json.dump(out, f, indent=4)

# %%
{
    "key" : "valus",
    "key2" : "dsd",
    "preson" : {
        "name": "yair",
        "age" : {
            "aa" :5
        }
    }
}

# %%
my_json = """
{
    "key": 5,
    "person" : [40,5,6,8],
    "aaa" : {
        "myname" : 4
        }

}"""

# %%
- pycharm

# %%
a = json.loads(my_json)

# %%
with open('myfile.json','w') as f:
    json.dump(a,f)

# %%
import json

# %% [markdown]
# JSON content is simply a formatted string. Lucky for us, Python users, JSON's "objects" look like Python's "dictionaries", and JSON's "arrays" look like Python's "lists". The module [`json`][json] implements a two-way tranformation between the JSON format an Python objects via two main methods:
#
# * **`load(f)`** - JSON file $\rightarrow$ Python object
# * **`dump(obj, f)`** - Python  object $\rightarrow$ JSON file
#
# [json]: https://docs.python.org/3/library/json.html "json module documentation"

# %% [markdown]
# ### Loading

# %% [markdown]
# Let's upload the example files and compare the results with their actual content.

# %% [markdown]
# > **Reference:** The hierarchical nature of JSON strings can makes them difficult to read. It is often convenient to start your data inspection with a [JSON viewer](http://jsonviewer.stack.hu/).

# %%
import sys

if 'google.colab' in sys.modules:
    from google.colab import files
    uploaded = files.upload()
# Out:
#      <input type="file" id="files-ab0ffb71-bb6b-4c54-a76d-aa14f06b2c9b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab0ffb71-bb6b-4c54-a76d-aa14f06b2c9b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ex2_array_of_objects.json to ex2_array_of_objects.json

# %%
with open('ex1_array_of_numbers.json') as f:
    a1 = json.load(f)
print(type(a1))
print(a1) 

# list dict
# Out:
# <class 'list'>
# [100, 500, 300, 200, 400]

# %%
with open('ex2_array_of_objects.json') as f:
    a2 = json.load(f)
print(type(a2))
print(type(a2[0]))
print(a2)
# Out:
# <class 'list'>
# <class 'dict'>
# [{'color': 'אדום', 'value': '#f00'}, {'color': 'green', 'value': '#0f0'}, {'color': 'blue', 'value': '#00f'}, {'color': 'cyan', 'value': '#0ff'}, {'color': 'magenta', 'value': '#f0f'}, {'color': 'yellow', 'value': '#ff0'}, {'color': 'black', 'value': '#000'}]

# %% [markdown]
# > **Your turn:** Inspect the content of the file *ex3_nested_object.json*, load its content, and create a list of all topping types.

# %% [markdown]
# ### Dumping

# %% [markdown]
# Like loading, we can also create JSON files from Python objects using the `dump()` method. Many arguments may control the appearance of the file, but to keep it human readable, the minimum is to use the _indent_ key-word.

# %%
with open('ex3_out.json', 'w') as f:
    json.dump(a2, f, indent=2)

# %% [markdown]
# # Example

# %% [markdown]
# Like most organizations, Youtube stores its movies' metadata in JSON files, and one such (fictive) file - *youtube.json* - is given as an example. We wish to write a function that is called when a new user is viewing the movie and caretes a new updated file.

# %% [markdown]
# After inspecting the structure of the file (again - use the [JSON viewer](http://jsonviewer.stack.hu/)), we see that `data` $\rightarrow$ `items` $\rightarrow$ 0 $\rightarrow$ `viewCount` will lead to the number of views.

# %%
with open('youtube.json') as f:
    youtube = json.load(f)

# %%
print(youtube['data']['items'][0]['viewCount'])

# %% [markdown]
# Thus we have:

# %%
def add_view(json_path):
    with open(json_path) as f:
        youtube = json.load(f)
    
    youtube['data']['items'][0]['viewCount'] += 1

    with open(json_path, 'w') as f:
        json.dump(youtube, f, indent=2)

# %% [markdown]
# > **Note:** Sometimes the JSON content is not associated with a file, but rather remains a formatted string. In this case the proper methods to use are the equivalent `loads(s)` and `dumps(obj)` ('s' is for 'string').

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Exercise 1

# %%
# import sys

# if 'google.colab' in sys.modules:
#     from google.colab import files
#     uploaded = files.upload()

# %%
[branch for branch in mcd['features'] if branch['properties']['driveThru'] == 'Y']
# Out:
# [{'geometry': {'type': 'Point', 'coordinates': [-80.140924, 25.789141]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI BEACH',
#    'zip': '33139-2420',
#    'freeWifi': 'Y',
#    'storeNumber': '14372',
#    'phone': '(305)672-7055',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/14372',
#    'playplace': 'N',
#    'address': '1601 ALTON RD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.218683, 25.765501]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33135',
#    'freeWifi': 'Y',
#    'storeNumber': '7408',
#    'phone': '(305)285-0974',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/7408',
#    'playplace': 'Y',
#    'address': '1400 SW 8TH ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.185108, 25.849872]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33138',
#    'freeWifi': 'Y',
#    'storeNumber': '11511',
#    'phone': '(305)756-0400',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/11511',
#    'playplace': 'N',
#    'address': '8116 BISCAYNE BLVD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.37197, 25.550894]},
#   'type': 'Feature',
#   'properties': {'city': 'HOMESTEAD',
#    'zip': '33032',
#    'freeWifi': 'Y',
#    'storeNumber': '34014',
#    'phone': '(305)258-7837',
#    'state': 'FL',
#    'playplace': 'N',
#    'address': '23351 SW 112TH AVE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'N',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.36734, 25.579132]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33157',
#    'freeWifi': 'Y',
#    'storeNumber': '12215',
#    'phone': '(305)254-3487',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/12215',
#    'playplace': 'Y',
#    'address': '10855 CARIBBEAN BLVD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.206753, 25.83273]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33150',
#    'freeWifi': 'Y',
#    'storeNumber': '7205',
#    'phone': '(305)751-5636',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/7205',
#    'playplace': 'N',
#    'address': '599 NW 62ND ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.292742, 25.701277]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33143-5003',
#    'freeWifi': 'Y',
#    'storeNumber': '792',
#    'phone': '(305)661-7131',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/792',
#    'playplace': 'N',
#    'address': '6150 S DIXIE HWY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.162258, 25.895759]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33181-2011',
#    'freeWifi': 'Y',
#    'storeNumber': '5944',
#    'phone': '(305)899-9578',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/5944',
#    'playplace': 'N',
#    'address': '13000 BISCAYNE BLVD.',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.274593, 25.715959]},
#   'type': 'Feature',
#   'properties': {'city': 'CORAL GABLES',
#    'zip': '33141',
#    'freeWifi': 'Y',
#    'storeNumber': '14782',
#    'phone': '(305)666-9919',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/14782',
#    'playplace': 'N',
#    'address': '1148 DIXIE HWY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.248185, 25.749746]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33145-2234',
#    'freeWifi': 'Y',
#    'storeNumber': '1789',
#    'phone': '(305)444-5466',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/1789',
#    'playplace': 'Y',
#    'address': '3280 CORAL WAY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.241236, 25.764843]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33135',
#    'freeWifi': 'Y',
#    'storeNumber': '7296',
#    'phone': '(305)541-4768',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/7296',
#    'playplace': 'N',
#    'address': '2940 SW 8TH ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.246245, 25.736552]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33133-3609',
#    'freeWifi': 'Y',
#    'storeNumber': '7147',
#    'phone': '(305)448-0531',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/7147',
#    'playplace': 'N',
#    'address': '3200 S DIXIE HWY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.121811, 25.940145]},
#   'type': 'Feature',
#   'properties': {'city': 'SUNNY ISLES BEACH',
#    'zip': '33160',
#    'freeWifi': 'Y',
#    'storeNumber': '12111',
#    'phone': '(305)937-4944',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/12111',
#    'playplace': 'N',
#    'address': '17730 COLLINS',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.232268, 25.809094]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33142',
#    'freeWifi': 'Y',
#    'storeNumber': '6589',
#    'phone': '(305)633-1385',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/6589',
#    'playplace': 'N',
#    'address': '2200 NW 36TH ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.336198, 25.636053]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33176',
#    'freeWifi': 'Y',
#    'storeNumber': '18735',
#    'phone': '(305)238-2615',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/18735',
#    'playplace': 'N',
#    'address': '14401 S DIXIE HWY',
#    'storeType': 'SHARED BLDNG',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.155511, 25.926693]},
#   'type': 'Feature',
#   'properties': {'city': 'NORTH MIAMI',
#    'zip': '33160',
#    'freeWifi': 'Y',
#    'storeNumber': '18490',
#    'phone': '(305)948-9081',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/18490',
#    'playplace': 'N',
#    'address': '2201 NE 163RD ST',
#    'storeType': 'GAS STATION',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.352483, 25.60092]},
#   'type': 'Feature',
#   'properties': {'city': 'PERRINE',
#    'zip': '33157',
#    'freeWifi': 'Y',
#    'storeNumber': '1856',
#    'phone': '(305)238-7129',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/1856',
#    'playplace': 'Y',
#    'address': '18295 S DIXIE HWY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.336189, 25.578119]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33189',
#    'freeWifi': 'Y',
#    'storeNumber': '16795',
#    'phone': '(305)235-5600',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/16795',
#    'playplace': 'Y',
#    'address': '20315 OLD CUTLER',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.189163, 25.809965]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33181',
#    'freeWifi': 'Y',
#    'storeNumber': '7166',
#    'phone': '(305)573-6064',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/7166',
#    'playplace': 'N',
#    'address': '3501 BISCAYNE BLVD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.211831, 25.773374]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33130',
#    'freeWifi': 'Y',
#    'storeNumber': '1819',
#    'phone': '(305)545-7788',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/1819',
#    'playplace': 'N',
#    'address': '1016 W FLAGLER ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.190172, 25.778003]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33132',
#    'freeWifi': 'Y',
#    'storeNumber': '12932',
#    'phone': '(305)371-8161',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/12932',
#    'playplace': 'N',
#    'address': '345 NE 2ND AVE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.198866, 25.766632]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33130',
#    'freeWifi': 'Y',
#    'storeNumber': '20598',
#    'phone': '(305)856-6770',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/20598',
#    'playplace': 'N',
#    'address': '299 S.W. 8TH STREET',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.522609, 25.004612]},
#   'type': 'Feature',
#   'properties': {'city': 'TAVENIER',
#    'zip': '33070',
#    'freeWifi': 'Y',
#    'storeNumber': '5090',
#    'phone': '(305)852-2463',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/5090',
#    'playplace': 'N',
#    'address': '91400 OVERSEAS HWY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.186104, 25.889943]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33181',
#    'freeWifi': 'Y',
#    'storeNumber': '14164',
#    'phone': '(305)899-2882',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/14164',
#    'playplace': 'N',
#    'address': '610 NE 125TH ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.26286, 25.763235]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33134',
#    'freeWifi': 'Y',
#    'storeNumber': '2287',
#    'phone': '(305)443-9366',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/2287',
#    'playplace': 'N',
#    'address': '4180 SW 9TH ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.434625, 25.477004]},
#   'type': 'Feature',
#   'properties': {'city': 'HOMESTEAD',
#    'zip': '33033',
#    'freeWifi': 'Y',
#    'storeNumber': '31341',
#    'phone': '(305)242-9774',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/31341',
#    'playplace': 'N',
#    'address': '2880 NE 8TH ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.329566, 25.652864]},
#   'type': 'Feature',
#   'properties': {'city': 'PINE CREST',
#    'zip': '33156',
#    'freeWifi': 'Y',
#    'storeNumber': '1167',
#    'phone': '(305)233-0058',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/1167',
#    'playplace': 'N',
#    'address': '12647 S DIXIE HWY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.548571, 42.359058]},
#   'type': 'Feature',
#   'properties': {'city': 'HADLEY',
#    'zip': '1035',
#    'freeWifi': 'Y',
#    'storeNumber': '35391',
#    'phone': '(413)582-0176',
#    'state': 'MA',
#    'playplace': 'N',
#    'address': '374 RUSSELL ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-80.210077, 25.859774]},
#   'type': 'Feature',
#   'properties': {'city': 'MIAMI',
#    'zip': '33150',
#    'freeWifi': 'Y',
#    'storeNumber': '5112',
#    'phone': '(305)759-1042',
#    'state': 'FL',
#    'storeUrl': 'http://www.mcflorida.com/5112',
#    'playplace': 'N',
#    'address': '9250 NW 7TH AVE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.63304, 42.059766]},
#   'type': 'Feature',
#   'properties': {'city': 'AGAWAM',
#    'zip': '1001',
#    'freeWifi': 'Y',
#    'storeNumber': '34251',
#    'phone': '(413)786-6863',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/34251',
#    'playplace': 'N',
#    'address': '868 SUFFIELD STREET',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.623996, 42.115792]},
#   'type': 'Feature',
#   'properties': {'city': 'WEST SPRINGFIELD',
#    'zip': '1089',
#    'freeWifi': 'Y',
#    'storeNumber': '356',
#    'phone': '(413)737-5153',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/356',
#    'playplace': 'N',
#    'address': '352 RIVERDALE RD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.585335, 42.024178]},
#   'type': 'Feature',
#   'properties': {'city': 'ENFIELD',
#    'zip': '6082',
#    'freeWifi': 'Y',
#    'storeNumber': '22257',
#    'phone': '(860)745-4314',
#    'state': 'CT',
#    'storeUrl': 'http://www.mcconnecticut.com/22257',
#    'playplace': 'Y',
#    'address': '34 ENDFIELD ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.553449, 42.142832]},
#   'type': 'Feature',
#   'properties': {'city': 'SPRINGFIELD',
#    'zip': '01104-3036',
#    'freeWifi': 'Y',
#    'storeNumber': '4847',
#    'phone': '(413)739-5529',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/4847',
#    'playplace': 'N',
#    'address': '771 PAGE BLVD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.603842, 42.095501]},
#   'type': 'Feature',
#   'properties': {'city': 'WEST SPRINGFIELD',
#    'zip': '1089',
#    'freeWifi': 'Y',
#    'storeNumber': '10335',
#    'phone': '(413)787-9951',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/10335',
#    'playplace': 'N',
#    'address': '429 MEMORIAL AVE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.489609, 42.143127]},
#   'type': 'Feature',
#   'properties': {'city': 'SPRINGFIELD',
#    'zip': '1129',
#    'freeWifi': 'Y',
#    'storeNumber': '6129',
#    'phone': '(413)543-3473',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/6129',
#    'playplace': 'Y',
#    'address': '1610 BOSTON POST RD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.584841, 42.120846]},
#   'type': 'Feature',
#   'properties': {'city': 'SPRINGFIELD',
#    'zip': '1103',
#    'freeWifi': 'Y',
#    'storeNumber': '26537',
#    'phone': '(413)731-1529',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/26537',
#    'playplace': 'N',
#    'address': '660 LIBERTY ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.579974, 41.989307]},
#   'type': 'Feature',
#   'properties': {'city': 'ENFIELD',
#    'zip': '6082',
#    'freeWifi': 'Y',
#    'storeNumber': '7620',
#    'phone': '(860)745-1484',
#    'state': 'CT',
#    'storeUrl': 'http://www.mcconnecticut.com/7620',
#    'playplace': 'N',
#    'address': '28 HAZARD AVE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.517735, 42.136741]},
#   'type': 'Feature',
#   'properties': {'city': 'SPRINGFIELD',
#    'zip': '1109',
#    'freeWifi': 'Y',
#    'storeNumber': '592',
#    'phone': '(413)783-2328',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/592',
#    'playplace': 'N',
#    'address': '809 BOSTON RD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.5461, 42.166754]},
#   'type': 'Feature',
#   'properties': {'city': 'CHICOPEE',
#    'zip': '1020',
#    'freeWifi': 'Y',
#    'storeNumber': '16283',
#    'phone': '(413)592-0646',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/16283',
#    'playplace': 'N',
#    'address': '350 BURNETT RD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.580214, 42.091392]},
#   'type': 'Feature',
#   'properties': {'city': 'SPRINGFIELD',
#    'zip': '1105',
#    'freeWifi': 'Y',
#    'storeNumber': '11926',
#    'phone': '(413)739-3534',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/11926',
#    'playplace': 'N',
#    'address': '360 MAIN ST.',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.574613, 42.197536]},
#   'type': 'Feature',
#   'properties': {'city': 'CHICOPEE',
#    'zip': '01020-3964',
#    'freeWifi': 'Y',
#    'storeNumber': '645',
#    'phone': '(413)532-5128',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/645',
#    'playplace': 'Y',
#    'address': '1460 MEMORIAL DRIVE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.565496, 42.111436]},
#   'type': 'Feature',
#   'properties': {'city': 'SPRINGFIELD',
#    'zip': '1105',
#    'freeWifi': 'Y',
#    'storeNumber': '15470',
#    'phone': '(413)788-1444',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/15470',
#    'playplace': 'N',
#    'address': '782 STATE STREET',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.72693, 42.113693]},
#   'type': 'Feature',
#   'properties': {'city': 'WESTFIELD',
#    'zip': '01085-3307',
#    'freeWifi': 'Y',
#    'storeNumber': '1550',
#    'phone': '(413)562-3428',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/1550',
#    'playplace': 'Y',
#    'address': '299 EAST MAIN STREET',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.741664, 42.134205]},
#   'type': 'Feature',
#   'properties': {'city': 'WESTFIELD',
#    'zip': '01085-1604',
#    'freeWifi': 'Y',
#    'storeNumber': '5954',
#    'phone': '(413)568-3595',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/5954',
#    'playplace': 'Y',
#    'address': '182 NORTH ELM STREET',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.785437, 42.025836]},
#   'type': 'Feature',
#   'properties': {'city': 'SOUTHWICK',
#    'zip': '1077',
#    'freeWifi': 'Y',
#    'storeNumber': '11575',
#    'phone': '(413)569-0870',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/11575',
#    'playplace': 'N',
#    'address': '214 COLLEGE HWY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.604074, 42.111282]},
#   'type': 'Feature',
#   'properties': {'city': 'SPRINGFIELD',
#    'zip': '01107-1906',
#    'freeWifi': 'Y',
#    'storeNumber': '11540',
#    'phone': '(413)781-2603',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/11540',
#    'playplace': 'N',
#    'address': '2392 MAIN ST.',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.613644, 42.164688]},
#   'type': 'Feature',
#   'properties': {'city': 'CHICOPEE',
#    'zip': '1013',
#    'freeWifi': 'Y',
#    'storeNumber': '6035',
#    'phone': '(413)592-5345',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/6035',
#    'playplace': 'N',
#    'address': '777 MEADOW ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.583619, 41.998263]},
#   'type': 'Feature',
#   'properties': {'city': 'ENFIELD',
#    'zip': '6082',
#    'freeWifi': 'Y',
#    'storeNumber': '2070',
#    'phone': '(860)741-0807',
#    'state': 'CT',
#    'storeUrl': 'http://www.mcconnecticut.com/2070',
#    'playplace': 'Y',
#    'address': '97 ELM ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.610596, 42.205811]},
#   'type': 'Feature',
#   'properties': {'city': 'HOLYOKE',
#    'zip': '1040',
#    'freeWifi': 'Y',
#    'storeNumber': '17735',
#    'phone': '(413)534-0228',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/17735',
#    'playplace': 'N',
#    'address': '285 MAPLE ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.629969, 42.186597]},
#   'type': 'Feature',
#   'properties': {'city': 'HOLYOKE',
#    'zip': '1040',
#    'freeWifi': 'Y',
#    'storeNumber': '1213',
#    'phone': '(413)532-5116',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/1213',
#    'playplace': 'N',
#    'address': '2194 N HAMPTON ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.511777, 41.985827]},
#   'type': 'Feature',
#   'properties': {'city': 'ENFIELD',
#    'zip': '6082',
#    'freeWifi': 'Y',
#    'storeNumber': '15009',
#    'phone': '(860)763-4122',
#    'state': 'CT',
#    'storeUrl': 'http://www.mcconnecticut.com/15009',
#    'playplace': 'N',
#    'address': '585 HAZARD AVE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.512954, 42.094618]},
#   'type': 'Feature',
#   'properties': {'city': 'SPRINGFIELD',
#    'zip': '01118-1806',
#    'freeWifi': 'Y',
#    'storeNumber': '1721',
#    'phone': '(413)783-8044',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/1721',
#    'playplace': 'Y',
#    'address': '1402 ALLEN STREET',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.633195, 42.328892]},
#   'type': 'Feature',
#   'properties': {'city': 'NORTHAMPTON',
#    'zip': '1060',
#    'freeWifi': 'Y',
#    'storeNumber': '862',
#    'phone': '(413)584-5073',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/862',
#    'playplace': 'N',
#    'address': '221 KING ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.481007, 42.167703]},
#   'type': 'Feature',
#   'properties': {'city': 'LUDLOW',
#    'zip': '1056',
#    'freeWifi': 'Y',
#    'storeNumber': '6099',
#    'phone': '(413)583-6827',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/6099',
#    'playplace': 'N',
#    'address': '420 CENTER ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.406243, 42.28835]},
#   'type': 'Feature',
#   'properties': {'city': 'BELCHERTOWN',
#    'zip': '1007',
#    'freeWifi': 'Y',
#    'storeNumber': '12064',
#    'phone': '(413)323-6498',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/12064',
#    'playplace': 'N',
#    'address': '148 N MAIN ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.624779, 42.585459]},
#   'type': 'Feature',
#   'properties': {'city': 'GREENFIELD',
#    'zip': '01301-9620',
#    'freeWifi': 'Y',
#    'storeNumber': '10735',
#    'phone': '(413)774-5311',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/10735',
#    'playplace': 'N',
#    'address': '208 MOHAWK TRAIL',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.670284, 42.27988]},
#   'type': 'Feature',
#   'properties': {'city': 'EASTHAMPTON',
#    'zip': '1027',
#    'freeWifi': 'Y',
#    'storeNumber': '6279',
#    'phone': '(413)527-5526',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/6279',
#    'playplace': 'Y',
#    'address': '121 N HAMPTON ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.323143, 42.174381]},
#   'type': 'Feature',
#   'properties': {'city': 'PALMER',
#    'zip': '1069',
#    'freeWifi': 'Y',
#    'storeNumber': '12009',
#    'phone': '(413)283-9095',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/12009',
#    'playplace': 'Y',
#    'address': '1184 THORNDIKE ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.454004, 42.169104]},
#   'type': 'Feature',
#   'properties': {'city': 'LUDLOW',
#    'zip': '1056',
#    'freeWifi': 'Y',
#    'storeNumber': '25931',
#    'phone': '(413)589-1790',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/25931',
#    'playplace': 'N',
#    'address': 'MASS PIKE I-90 SRVCE AREA 3E MILEPOST 89',
#    'storeType': 'TOLLWAY',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.249906, 42.256992]},
#   'type': 'Feature',
#   'properties': {'city': 'WARE',
#    'zip': '1082',
#    'freeWifi': 'Y',
#    'storeNumber': '2116',
#    'phone': '(413)967-3485',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/2116',
#    'playplace': 'N',
#    'address': '117-119 WEST ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.594488, 42.599834]},
#   'type': 'Feature',
#   'properties': {'city': 'GREENFIELD',
#    'zip': '1301',
#    'freeWifi': 'Y',
#    'storeNumber': '1439',
#    'phone': '(413)774-3618',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/1439',
#    'playplace': 'Y',
#    'address': '285 FEDERAL ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.99086, 42.563297]},
#   'type': 'Feature',
#   'properties': {'city': 'GARDNER',
#    'zip': '1440',
#    'freeWifi': 'Y',
#    'storeNumber': '2223',
#    'phone': '(978)632-9859',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/2223',
#    'playplace': 'N',
#    'address': '223 TIMPANY BLVD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.795265, 42.319057]},
#   'type': 'Feature',
#   'properties': {'city': 'WORCESTER',
#    'zip': '1606',
#    'freeWifi': 'Y',
#    'storeNumber': '1775',
#    'phone': '(508)852-1350',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/1775',
#    'playplace': 'Y',
#    'address': '766 W BOYLSTON ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.826126, 42.247734]},
#   'type': 'Feature',
#   'properties': {'city': 'WORCESTER',
#    'zip': '01603-2418',
#    'freeWifi': 'Y',
#    'storeNumber': '373',
#    'phone': '(508)757-5357',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/373',
#    'playplace': 'N',
#    'address': '995 MAIN STREET',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.012413, 42.233025]},
#   'type': 'Feature',
#   'properties': {'city': 'SPENCER',
#    'zip': '1562',
#    'freeWifi': 'Y',
#    'storeNumber': '6050',
#    'phone': '(508)885-3355',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/6050',
#    'playplace': 'Y',
#    'address': '59 W MAIN ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.78373, 42.553749]},
#   'type': 'Feature',
#   'properties': {'city': 'FITCHBURG',
#    'zip': '1420',
#    'freeWifi': 'Y',
#    'storeNumber': '6703',
#    'phone': '(978)342-2862',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/6703',
#    'playplace': 'N',
#    'address': '114 WHALON ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.039146, 42.678806]},
#   'type': 'Feature',
#   'properties': {'city': 'WINCHENDON',
#    'zip': '1475',
#    'freeWifi': 'Y',
#    'storeNumber': '12061',
#    'phone': '(978)297-3528',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/12061',
#    'playplace': 'N',
#    'address': '235 SPRING ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.774071, 42.579613]},
#   'type': 'Feature',
#   'properties': {'city': 'FITCHBURG',
#    'zip': '1420',
#    'freeWifi': 'Y',
#    'storeNumber': '466',
#    'phone': '(978)343-9618',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/466',
#    'playplace': 'N',
#    'address': '334 JOHN FITCH HIGHWAY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.837723, 42.339478]},
#   'type': 'Feature',
#   'properties': {'city': 'HOLDEN',
#    'zip': '1520',
#    'freeWifi': 'Y',
#    'storeNumber': '4753',
#    'phone': '(508)829-5615',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/4753',
#    'playplace': 'Y',
#    'address': '638 S MAIN ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.772675, 42.295776]},
#   'type': 'Feature',
#   'properties': {'city': 'WORCESTER',
#    'zip': '1608',
#    'freeWifi': 'Y',
#    'storeNumber': '6154',
#    'phone': '(508)852-5417',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/6154',
#    'playplace': 'Y',
#    'address': '548 LINCOLN ST.',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.770973, 42.272633]},
#   'type': 'Feature',
#   'properties': {'city': 'WORCESTER',
#    'zip': '1604',
#    'freeWifi': 'Y',
#    'storeNumber': '22710',
#    'phone': '(508)757-9996',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/22710',
#    'playplace': 'N',
#    'address': '465 SHREWSBURY ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.760483, 42.542198]},
#   'type': 'Feature',
#   'properties': {'city': 'LEOMINSTER',
#    'zip': '1453',
#    'freeWifi': 'Y',
#    'storeNumber': '1323',
#    'phone': '(978)534-9762',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/1323',
#    'playplace': 'N',
#    'address': '302 N MAIN STREET',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.254883, 42.581505]},
#   'type': 'Feature',
#   'properties': {'city': 'ATHOL',
#    'zip': '1331',
#    'freeWifi': 'Y',
#    'storeNumber': '7204',
#    'phone': '(978)249-9866',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/7204',
#    'playplace': 'Y',
#    'address': '100 BROOKSIDE RD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.024897, 42.139797]},
#   'type': 'Feature',
#   'properties': {'city': 'CHARLTON CITY',
#    'zip': '1508',
#    'freeWifi': 'N',
#    'storeNumber': '25933',
#    'phone': '(508)248-0517',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/25933',
#    'playplace': 'N',
#    'address': 'MASSACHUSETTS TURNPIKE',
#    'storeType': 'TOLLWAY',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.87056, 42.178829]},
#   'type': 'Feature',
#   'properties': {'city': 'AUBURN',
#    'zip': '01501-1323',
#    'freeWifi': 'Y',
#    'storeNumber': '7996',
#    'phone': '(508)832-7100',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/7996',
#    'playplace': 'Y',
#    'address': '813 SOUTHBRIDGE ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.795837, 42.211311]},
#   'type': 'Feature',
#   'properties': {'city': 'WORCESTER',
#    'zip': '1607',
#    'freeWifi': 'Y',
#    'storeNumber': '5798',
#    'phone': '(508)752-1097',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/5798',
#    'playplace': 'Y',
#    'address': 'RT 20 & GREENWOOD ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.85363, 42.275879]},
#   'type': 'Feature',
#   'properties': {'city': 'WORCESTER',
#    'zip': '1603',
#    'freeWifi': 'Y',
#    'storeNumber': '11531',
#    'phone': '(508)754-8812',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/11531',
#    'playplace': 'N',
#    'address': '595 MILL ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.818138, 42.582439]},
#   'type': 'Feature',
#   'properties': {'city': 'FITCHBURG',
#    'zip': '1420',
#    'freeWifi': 'Y',
#    'storeNumber': '11712',
#    'phone': '(978)345-4397',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/11712',
#    'playplace': 'N',
#    'address': '550 KIMBALL ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.835716, 42.208801]},
#   'type': 'Feature',
#   'properties': {'city': 'AUBURN',
#    'zip': '01501-2458',
#    'freeWifi': 'Y',
#    'storeNumber': '1672',
#    'phone': '(508)832-3744',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/1672',
#    'playplace': 'N',
#    'address': '72 AUBURN STREET',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.753189, 42.274853]},
#   'type': 'Feature',
#   'properties': {'city': 'SHREWSBURY',
#    'zip': '1545',
#    'freeWifi': 'Y',
#    'storeNumber': '26790',
#    'phone': '(508)890-2777',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/26790',
#    'playplace': 'N',
#    'address': '31 BOSTON TURNPIKE RD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.964109, 42.156404]},
#   'type': 'Feature',
#   'properties': {'city': 'CHARLTON',
#    'zip': '1507',
#    'freeWifi': 'Y',
#    'storeNumber': '25934',
#    'phone': '(508)248-6788',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/25934',
#    'playplace': 'N',
#    'address': 'MASS PIKE I-90 SRVCE AREA 6W MILEPOST 89',
#    'storeType': 'TOLLWAY',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.987288, 42.145172]},
#   'type': 'Feature',
#   'properties': {'city': 'CHARLTON',
#    'zip': '1507',
#    'freeWifi': 'Y',
#    'storeNumber': '29570',
#    'phone': '(508)248-7040',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/29570',
#    'playplace': 'N',
#    'address': '38 WORCESTER ROAD',
#    'storeType': 'GAS STATION',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.743767, 42.532749]},
#   'type': 'Feature',
#   'properties': {'city': 'LEOMINSTER',
#    'zip': '1453',
#    'freeWifi': 'Y',
#    'storeNumber': '5020',
#    'phone': '(978)534-9706',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/5020',
#    'playplace': 'N',
#    'address': '247 MILL ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.932539, 42.195435]},
#   'type': 'Feature',
#   'properties': {'city': 'BLANDFORD',
#    'zip': '1008',
#    'freeWifi': 'Y',
#    'storeNumber': '25929',
#    'phone': '(413)848-2284',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/25929',
#    'playplace': 'N',
#    'address': 'MASS PIKE W TRAVEL PLAZA',
#    'storeType': 'TOLLWAY',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.934186, 42.194276]},
#   'type': 'Feature',
#   'properties': {'city': 'BLANDFORD',
#    'zip': '1008',
#    'freeWifi': 'N',
#    'storeNumber': '25930',
#    'phone': '(413)848-2518',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/25930',
#    'playplace': 'N',
#    'address': 'MASS PIKE I-90 E MILEPOST 29',
#    'storeType': 'TOLLWAY',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-73.274503, 42.298423]},
#   'type': 'Feature',
#   'properties': {'city': 'LEE',
#    'zip': '1238',
#    'freeWifi': 'Y',
#    'storeNumber': '25928',
#    'phone': '(413)243-6695',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/25928',
#    'playplace': 'N',
#    'address': '240 WEST ROAD',
#    'storeType': 'TOLLWAY',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-73.240801, 42.299152]},
#   'type': 'Feature',
#   'properties': {'city': 'LEE',
#    'zip': '1238',
#    'freeWifi': 'Y',
#    'storeNumber': '14735',
#    'phone': '(413)243-2253',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/14735',
#    'playplace': 'N',
#    'address': '245 HOUSATONIC ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-73.058495, 41.919404]},
#   'type': 'Feature',
#   'properties': {'city': 'WINSTED',
#    'zip': '6098',
#    'freeWifi': 'Y',
#    'storeNumber': '2109',
#    'phone': '(860)379-6904',
#    'state': 'CT',
#    'storeUrl': 'http://www.mcconnecticut.com/2109',
#    'playplace': 'N',
#    'address': '15 S MAIN ST RTE 44',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-73.274697, 42.296908]},
#   'type': 'Feature',
#   'properties': {'city': 'LEE',
#    'zip': '1238',
#    'freeWifi': 'Y',
#    'storeNumber': '25927',
#    'phone': '(413)243-4666',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/25927',
#    'playplace': 'N',
#    'address': 'MASS PIKE E TRAVEL PLAZA',
#    'storeType': 'TOLLWAY',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.089508, 42.112263]},
#   'type': 'Feature',
#   'properties': {'city': 'STURBRIDGE',
#    'zip': '1566',
#    'freeWifi': 'Y',
#    'storeNumber': '5073',
#    'phone': '(508)347-5856',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/5073',
#    'playplace': 'N',
#    'address': '366 MAIN ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.330545, 41.969567]},
#   'type': 'Feature',
#   'properties': {'city': 'STAFFORD SPRINGS',
#    'zip': '6076',
#    'freeWifi': 'Y',
#    'storeNumber': '4621',
#    'phone': '(860)684-9697',
#    'state': 'CT',
#    'storeUrl': 'http://www.mcconnecticut.com/4621',
#    'playplace': 'Y',
#    'address': '89 W STAFFORD RD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.859802, 42.117058]},
#   'type': 'Feature',
#   'properties': {'city': 'OXFORD',
#    'zip': '1540',
#    'freeWifi': 'Y',
#    'storeNumber': '13143',
#    'phone': '(508)987-2047',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/13143',
#    'playplace': 'N',
#    'address': '26 A SUTTON AVE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.009109, 42.06863]},
#   'type': 'Feature',
#   'properties': {'city': 'SOUTHBRIDGE',
#    'zip': '1550',
#    'freeWifi': 'Y',
#    'storeNumber': '2560',
#    'phone': '(508)764-2196',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/2560',
#    'playplace': 'Y',
#    'address': '515 E MAIN ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.873451, 42.055595]},
#   'type': 'Feature',
#   'properties': {'city': 'WEBSTER',
#    'zip': '1570',
#    'freeWifi': 'Y',
#    'storeNumber': '1823',
#    'phone': '(508)943-9009',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/1823',
#    'playplace': 'N',
#    'address': '44 E MAIN ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-73.203972, 42.46852]},
#   'type': 'Feature',
#   'properties': {'city': 'PITTSFIELD',
#    'zip': '1201',
#    'freeWifi': 'Y',
#    'storeNumber': '12045',
#    'phone': '(413)442-4602',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/12045',
#    'playplace': 'N',
#    'address': 'ALLENDALE SHOPPING CTR',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-73.274932, 42.442632]},
#   'type': 'Feature',
#   'properties': {'city': 'PITTSFIELD',
#    'zip': '1201',
#    'freeWifi': 'Y',
#    'storeNumber': '1824',
#    'phone': '(413)442-4629',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/1824',
#    'playplace': 'N',
#    'address': '445 W HOUSATONIC ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-73.345374, 42.209996]},
#   'type': 'Feature',
#   'properties': {'city': 'GREAT BARRINGTON',
#    'zip': '1230',
#    'freeWifi': 'Y',
#    'storeNumber': '2809',
#    'phone': '(413)528-0434',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/2809',
#    'playplace': 'N',
#    'address': '302 STOCKBRIDGE RD (RT 7)',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-73.120178, 42.619229]},
#   'type': 'Feature',
#   'properties': {'city': 'ADAMS',
#    'zip': '1220',
#    'freeWifi': 'Y',
#    'storeNumber': '4593',
#    'phone': '(413)743-4678',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/4593',
#    'playplace': 'N',
#    'address': '2 COMMERCIAL ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-73.107984, 42.700757]},
#   'type': 'Feature',
#   'properties': {'city': 'NORTH ADAMS',
#    'zip': '1247',
#    'freeWifi': 'Y',
#    'storeNumber': '1147',
#    'phone': '(413)664-7272',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/1147',
#    'playplace': 'N',
#    'address': '17 27 UNION/EAGLE ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.66972, 41.928487]},
#   'type': 'Feature',
#   'properties': {'city': 'WINDSOR LOCKS',
#    'zip': '6096',
#    'freeWifi': 'Y',
#    'storeNumber': '2617',
#    'phone': '(860)623-4373',
#    'state': 'CT',
#    'storeUrl': 'http://www.mcconnecticut.com/2617',
#    'playplace': 'N',
#    'address': '195 TURNPIKE RD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.868365, 41.817951]},
#   'type': 'Feature',
#   'properties': {'city': 'SIMSBURY',
#    'zip': '6070',
#    'freeWifi': 'Y',
#    'storeNumber': '1240',
#    'phone': '(860)651-9589',
#    'state': 'CT',
#    'storeUrl': 'http://www.mcconnecticut.com/1240',
#    'playplace': 'Y',
#    'address': '22 ALBANY TPKE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.8984, 41.826094]},
#   'type': 'Feature',
#   'properties': {'city': 'CANTON',
#    'zip': '6019',
#    'freeWifi': 'Y',
#    'storeNumber': '17261',
#    'phone': '(860)693-9284',
#    'state': 'CT',
#    'storeUrl': 'http://www.mcconnecticut.com/17261',
#    'playplace': 'N',
#    'address': '220 ALBANY TPKE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-73.078732, 41.82062]},
#   'type': 'Feature',
#   'properties': {'city': 'TORRINGTON',
#    'zip': '06790-3131',
#    'freeWifi': 'Y',
#    'storeNumber': '17764',
#    'phone': '(860)626-8008',
#    'state': 'CT',
#    'storeUrl': 'http://www.mcconnecticut.com/17764',
#    'playplace': 'N',
#    'address': '1858 E MAIN ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.46301, 41.888559]},
#   'type': 'Feature',
#   'properties': {'city': 'ELLINGTON',
#    'zip': '6029',
#    'freeWifi': 'Y',
#    'storeNumber': '32393',
#    'phone': '(860)871-0200',
#    'state': 'CT',
#    'storeUrl': 'http://www.mcconnecticut.com/32393',
#    'playplace': 'N',
#    'address': 'ROUTE 83',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.687073, 42.432442]},
#   'type': 'Feature',
#   'properties': {'city': 'CLINTON',
#    'zip': '1510',
#    'freeWifi': 'Y',
#    'storeNumber': '1999',
#    'phone': '(978)365-9894',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/1999',
#    'playplace': 'N',
#    'address': '1040 MAIN ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-71.758957, 42.244755]},
#   'type': 'Feature',
#   'properties': {'city': 'WORCESTER',
#    'zip': '01604-2034',
#    'freeWifi': 'Y',
#    'storeNumber': '1650',
#    'phone': '(508)799-7606',
#    'state': 'MA',
#    'storeUrl': 'http://www.mcmassachusetts.com/1650',
#    'playplace': 'N',
#    'address': '982 GRAFTON STREET',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-73.204756, 42.895475]},
#   'type': 'Feature',
#   'properties': {'city': 'BENNINGTON',
#    'zip': '5201',
#    'freeWifi': 'Y',
#    'storeNumber': '22198',
#    'phone': '(802)442-8803',
#    'state': 'VT',
#    'storeUrl': 'http://www.mcvermont.com/22198',
#    'playplace': 'Y',
#    'address': '112 NORTHSIDE DR',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.557579, 42.882069]},
#   'type': 'Feature',
#   'properties': {'city': 'BRATTLEBORO',
#    'zip': '5301',
#    'freeWifi': 'Y',
#    'storeNumber': '3021',
#    'phone': '(802)254-8528',
#    'state': 'VT',
#    'storeUrl': 'http://www.mcvermont.com/3021',
#    'playplace': 'N',
#    'address': '1027 PUTNEY RD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-72.429796, 41.856265]},
#   'type': 'Feature',
#   'properties': {'city': 'ROCKVILLE',
#    'zip': '6066',
#    'freeWifi': 'Y',
#    'storeNumber': '27610',
#    'phone': '(860)871-6118',
#    'state': 'CT',
#    'storeUrl': 'http://www.mcconnecticut.com/27610',
#    'playplace': 'N',
#    'address': '74 RESERVOIR ROAD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-73.675265, 42.738823]},
#   'type': 'Feature',
#   'properties': {'city': 'TROY',
#    'zip': '12180',
#    'freeWifi': 'Y',
#    'storeNumber': '34636',
#    'phone': '(518)266-1215',
#    'state': 'NY',
#    'playplace': 'N',
#    'address': 'HOOSICK ST. & 15TH ST.',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-73.64686, 42.696889]},
#   'type': 'Feature',
#   'properties': {'city': 'WYNANTSKILL',
#    'zip': '12198',
#    'freeWifi': 'Y',
#    'storeNumber': '4272',
#    'phone': '(518)283-2089',
#    'state': 'NY',
#    'storeUrl': 'http://www.mcnewyork.com/4272',
#    'playplace': 'N',
#    'address': 'MAIN AVE RT 66',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-73.767986, 42.254637]},
#   'type': 'Feature',
#   'properties': {'city': 'HUDSON',
#    'zip': '12534',
#    'freeWifi': 'Y',
#    'storeNumber': '6071',
#    'phone': '(518)828-4811',
#    'state': 'NY',
#    'storeUrl': 'http://www.mcnewyork.com/6071',
#    'playplace': 'N',
#    'address': 'FAIRVIEW AVE EXTENSION',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-73.325632, 42.025151]},
#   'type': 'Feature',
#   'properties': {'city': 'NORTH CANAAN',
#    'zip': '6018',
#    'freeWifi': 'Y',
#    'storeNumber': '7809',
#    'phone': '(860)824-5281',
#    'state': 'CT',
#    'storeUrl': 'http://www.mcconnecticut.com/7809',
#    'playplace': 'N',
#    'address': '18 MAIN ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
# ...
#    'storeNumber': '10492',
#    'phone': '(302)733-0818',
#    'state': 'DE',
#    'storeUrl': 'http://www.mcdelaware.com/10492',
#    'playplace': 'Y',
#    'address': '2351 S COLLEGE AVE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.232526, 39.42608]},
#   'type': 'Feature',
#   'properties': {'city': 'BRIDGETON',
#    'zip': '8302',
#    'freeWifi': 'Y',
#    'storeNumber': '19571',
#    'phone': '(856)453-4787',
#    'state': 'NJ',
#    'playplace': 'N',
#    'address': '56 E BROAD ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'N',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.72523, 39.450991]},
#   'type': 'Feature',
#   'properties': {'city': 'MIDDLETOWN',
#    'zip': '19709',
#    'freeWifi': 'Y',
#    'storeNumber': '20274',
#    'phone': '(302)378-3936',
#    'state': 'DE',
#    'storeUrl': 'http://www.mcdelaware.com/20274',
#    'playplace': 'Y',
#    'address': '580 MIDDLETOWN-WARWICK ROAD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.209247, 39.45952]},
#   'type': 'Feature',
#   'properties': {'city': 'BRIDGETON',
#    'zip': '8302',
#    'freeWifi': 'Y',
#    'storeNumber': '2400',
#    'phone': '(856)451-9165',
#    'state': 'NJ',
#    'storeUrl': 'http://www.mcnewjersey.com/2400',
#    'playplace': 'N',
#    'address': '1056 N PEARL ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-74.578023, 39.278949]},
#   'type': 'Feature',
#   'properties': {'city': 'OCEAN CITY',
#    'zip': '8226',
#    'freeWifi': 'Y',
#    'storeNumber': '4592',
#    'phone': '(609)398-6554',
#    'state': 'NJ',
#    'storeUrl': 'http://www.mcnewjersey.com/4592',
#    'playplace': 'Y',
#    'address': '900 WEST AVE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-74.598249, 39.327643]},
#   'type': 'Feature',
#   'properties': {'city': 'SOMERS POINTS',
#    'zip': '8244',
#    'freeWifi': 'Y',
#    'storeNumber': '17782',
#    'phone': '(609)926-5900',
#    'state': 'NJ',
#    'storeUrl': 'http://www.mcnewjersey.com/17782',
#    'playplace': 'N',
#    'address': '401 NEW RD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.166119, 39.995854]},
#   'type': 'Feature',
#   'properties': {'city': 'PHILADELPHIA',
#    'zip': '19132',
#    'freeWifi': 'Y',
#    'storeNumber': '10913',
#    'phone': '(215)225-6489',
#    'state': 'PA',
#    'storeUrl': 'http://www.mcpennsylvania.com/10913',
#    'playplace': 'N',
#    'address': '2101 W LEHIGH',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.155994, 39.985228]},
#   'type': 'Feature',
#   'properties': {'city': 'PHILADELPHIA',
#    'zip': '19122',
#    'freeWifi': 'Y',
#    'storeNumber': '1962',
#    'phone': '(215)765-2520',
#    'state': 'PA',
#    'storeUrl': 'http://www.mcpennsylvania.com/1962',
#    'playplace': 'N',
#    'address': '2109 N BROAD ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-74.819667, 39.087192]},
#   'type': 'Feature',
#   'properties': {'city': 'CAPE MAY COURT HOUSE',
#    'zip': '8210',
#    'freeWifi': 'Y',
#    'storeNumber': '4617',
#    'phone': '(609)465-4604',
#    'state': 'NJ',
#    'storeUrl': 'http://www.mcnewjersey.com/4617',
#    'playplace': 'N',
#    'address': '227 N MAIN ST(BUCKS COUNTY COFFEE)',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-74.702539, 39.209375]},
#   'type': 'Feature',
#   'properties': {'city': 'SEAVILLE',
#    'zip': '8230',
#    'freeWifi': 'Y',
#    'storeNumber': '13461',
#    'phone': '(609)624-1600',
#    'state': 'NJ',
#    'storeUrl': 'http://www.mcnewjersey.com/13461',
#    'playplace': 'Y',
#    'address': '2087 RT 9',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.134762, 38.731586]},
#   'type': 'Feature',
#   'properties': {'city': 'REHOBOTH BEACH',
#    'zip': '19971',
#    'freeWifi': 'Y',
#    'storeNumber': '24322',
#    'phone': '(302)645-4885',
#    'state': 'DE',
#    'storeUrl': 'http://www.mcdelaware.com/24322',
#    'playplace': 'Y',
#    'address': '18878 COASTAL HWY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-74.941948, 38.973774]},
#   'type': 'Feature',
#   'properties': {'city': 'NORTH CAPE MAY',
#    'zip': '8204',
#    'freeWifi': 'Y',
#    'storeNumber': '5453',
#    'phone': '(609)884-0840',
#    'state': 'NJ',
#    'storeUrl': 'http://www.mcnewjersey.com/5453',
#    'playplace': 'N',
#    'address': '3857 BAYSHORE RD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-74.827639, 38.985948]},
#   'type': 'Feature',
#   'properties': {'city': 'WILDWOOD',
#    'zip': '8260',
#    'freeWifi': 'Y',
#    'storeNumber': '3798',
#    'phone': '(609)522-4470',
#    'state': 'NJ',
#    'storeUrl': 'http://www.mcnewjersey.com/3798',
#    'playplace': 'N',
#    'address': 'RT 47 & PARK BLVD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-74.793369, 39.01012]},
#   'type': 'Feature',
#   'properties': {'city': 'NORTH WILDWOOD',
#    'zip': '8260',
#    'freeWifi': 'Y',
#    'storeNumber': '6238',
#    'phone': '(609)522-1011',
#    'state': 'NJ',
#    'storeUrl': 'http://www.mcnewjersey.com/6238',
#    'playplace': 'N',
#    'address': '130 WEST SPRUCE AVENUE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.398376, 38.692585]},
#   'type': 'Feature',
#   'properties': {'city': 'GEORGETOWN',
#    'zip': '19947',
#    'freeWifi': 'Y',
#    'storeNumber': '4959',
#    'phone': '(302)856-6101',
#    'state': 'DE',
#    'storeUrl': 'http://www.mcdelaware.com/4959',
#    'playplace': 'N',
#    'address': '20817 DUPONT BLVD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.055672, 38.52108]},
#   'type': 'Feature',
#   'properties': {'city': 'BETHANY BEACH',
#    'zip': '19930',
#    'freeWifi': 'Y',
#    'storeNumber': '7959',
#    'phone': '(302)537-1226',
#    'state': 'DE',
#    'storeUrl': 'http://www.mcdelaware.com/7959',
#    'playplace': 'N',
#    'address': 'USHY 1 & ADDY RD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.531019, 39.182956]},
#   'type': 'Feature',
#   'properties': {'city': 'DOVER',
#    'zip': '19901-2000',
#    'freeWifi': 'Y',
#    'storeNumber': '3822',
#    'phone': '(302)674-8573',
#    'state': 'DE',
#    'storeUrl': 'http://www.mcdelaware.com/3822',
#    'playplace': 'N',
#    'address': '879 N. DUPONT HIGHWAY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.441217, 38.918849]},
#   'type': 'Feature',
#   'properties': {'city': 'MILFORD',
#    'zip': '19963-1001',
#    'freeWifi': 'Y',
#    'storeNumber': '5309',
#    'phone': '(302)422-5161',
#    'state': 'DE',
#    'storeUrl': 'http://www.mcdelaware.com/5309',
#    'playplace': 'Y',
#    'address': '653 NORTH DUPONT HIGHWAY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.51583, 39.145969]},
#   'type': 'Feature',
#   'properties': {'city': 'DOVER',
#    'zip': '19901-4419',
#    'freeWifi': 'Y',
#    'storeNumber': '1429',
#    'phone': '(302)674-8080',
#    'state': 'DE',
#    'storeUrl': 'http://www.mcdelaware.com/1429',
#    'playplace': 'N',
#    'address': '915 SOUTH DUPONT HIGHWAY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.28331, 38.571258]},
#   'type': 'Feature',
#   'properties': {'city': 'MILLSBORO',
#    'zip': '19966',
#    'freeWifi': 'Y',
#    'storeNumber': '34154',
#    'phone': '(302)933-0750',
#    'state': 'DE',
#    'playplace': 'N',
#    'address': '30255 COMMERCE DR',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.566181, 38.929751]},
#   'type': 'Feature',
#   'properties': {'city': 'HARRINGTON',
#    'zip': '19952',
#    'freeWifi': 'Y',
#    'storeNumber': '12681',
#    'phone': '(302)398-0222',
#    'state': 'DE',
#    'storeUrl': 'http://www.mcdelaware.com/12681',
#    'playplace': 'N',
#    'address': '16758 S DUPONT HWY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.194071, 38.633944]},
#   'type': 'Feature',
#   'properties': {'city': 'MILLSBORO',
#    'zip': '19966',
#    'freeWifi': 'Y',
#    'storeNumber': '31570',
#    'phone': '(302)947-2602',
#    'state': 'DE',
#    'storeUrl': 'http://www.mcdelaware.com/31570',
#    'playplace': 'N',
#    'address': '24943 JOHN J. WILLIAMS HWY.',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.494105, 39.129375]},
#   'type': 'Feature',
#   'properties': {'city': 'DOVER',
#    'zip': '19901-5845',
#    'freeWifi': 'Y',
#    'storeNumber': '11185',
#    'phone': '(302)735-4537',
#    'state': 'DE',
#    'storeUrl': 'http://www.mcdelaware.com/11185',
#    'playplace': 'N',
#    'address': '1704 EAST LEBANON RD - ROUTE 10',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.555159, 39.198839]},
#   'type': 'Feature',
#   'properties': {'city': 'DOVER',
#    'zip': '19901',
#    'freeWifi': 'Y',
#    'storeNumber': '16850',
#    'phone': '(302)734-0950',
#    'state': 'DE',
#    'storeUrl': 'http://www.mcdelaware.com/16850',
#    'playplace': 'N',
#    'address': '1788N DUPONT HIGHWAY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.607929, 39.306704]},
#   'type': 'Feature',
#   'properties': {'city': 'SMYRNA',
#    'zip': '19977',
#    'freeWifi': 'Y',
#    'storeNumber': '2774',
#    'phone': '(302)653-6330',
#    'state': 'DE',
#    'storeUrl': 'http://www.mcdelaware.com/2774',
#    'playplace': 'N',
#    'address': '333 N DUPONT HWY',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.558162, 39.158585]},
#   'type': 'Feature',
#   'properties': {'city': 'DOVER',
#    'zip': '19901-3315',
#    'freeWifi': 'Y',
#    'storeNumber': '11303',
#    'phone': '(302)674-2095',
#    'state': 'DE',
#    'storeUrl': 'http://www.mcdelaware.com/11303',
#    'playplace': 'N',
#    'address': '1424 FORREST AVE - ROUTE 8',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-74.779661, 40.250119]},
#   'type': 'Feature',
#   'properties': {'city': 'TRENTON',
#    'zip': '8638',
#    'freeWifi': 'Y',
#    'storeNumber': '295',
#    'phone': '(609)883-2815',
#    'state': 'NJ',
#    'storeUrl': 'http://www.mcnewjersey.com/295',
#    'playplace': 'N',
#    'address': '1885 N OLDEN AVE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-74.966217, 40.363557]},
#   'type': 'Feature',
#   'properties': {'city': 'NEW HOPE',
#    'zip': '18938-1432',
#    'freeWifi': 'Y',
#    'storeNumber': '5843',
#    'phone': '(215)862-5061',
#    'state': 'PA',
#    'storeUrl': 'http://www.mcpennsylvania.com/5843',
#    'playplace': 'Y',
#    'address': '324 W BRIDGE ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.011158, 40.213555]},
#   'type': 'Feature',
#   'properties': {'city': 'RICHBORO',
#    'zip': '18954',
#    'freeWifi': 'Y',
#    'storeNumber': '5242',
#    'phone': '(215)364-3020',
#    'state': 'PA',
#    'storeUrl': 'http://www.mcpennsylvania.com/5242',
#    'playplace': 'Y',
#    'address': '950 2ND STR PIKE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.046737, 40.166557]},
#   'type': 'Feature',
#   'properties': {'city': 'SOUTHAMPTON',
#    'zip': '18966',
#    'freeWifi': 'Y',
#    'storeNumber': '1341',
#    'phone': '(215)355-5696',
#    'state': 'PA',
#    'storeUrl': 'http://www.mcpennsylvania.com/1341',
#    'playplace': 'N',
#    'address': '338 2ND ST PIKE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.145927, 40.386278]},
#   'type': 'Feature',
#   'properties': {'city': 'PIPERSVILLE',
#    'zip': '18947',
#    'freeWifi': 'Y',
#    'storeNumber': '13963',
#    'phone': '(215)766-4860',
#    'state': 'PA',
#    'storeUrl': 'http://www.mcpennsylvania.com/13963',
#    'playplace': 'Y',
#    'address': '5857 EASTON ROAD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.08595, 40.260093]},
#   'type': 'Feature',
#   'properties': {'city': 'JAMISON',
#    'zip': '18929',
#    'freeWifi': 'Y',
#    'storeNumber': '23554',
#    'phone': '(215)491-5720',
#    'state': 'PA',
#    'storeUrl': 'http://www.mcpennsylvania.com/23554',
#    'playplace': 'Y',
#    'address': '2395 YORK RD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.105904, 40.179979]},
#   'type': 'Feature',
#   'properties': {'city': 'HATBORO',
#    'zip': '19040',
#    'freeWifi': 'Y',
#    'storeNumber': '752',
#    'phone': '(215)443-7795',
#    'state': 'PA',
#    'storeUrl': 'http://www.mcpennsylvania.com/752',
#    'playplace': 'N',
#    'address': '121 N YORK RD',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.18908, 40.296413]},
#   'type': 'Feature',
#   'properties': {'city': 'DOYLESTOWN',
#    'zip': '18901',
#    'freeWifi': 'Y',
#    'storeNumber': '15965',
#    'phone': '(215)340-2900',
#    'state': 'PA',
#    'storeUrl': 'http://www.mcpennsylvania.com/15965',
#    'playplace': 'N',
#    'address': '800 TOWN CENTER',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.130079, 40.322711]},
#   'type': 'Feature',
#   'properties': {'city': 'DOYLESTOWN',
#    'zip': '18901',
#    'freeWifi': 'Y',
#    'storeNumber': '4353',
#    'phone': '(215)348-7717',
#    'state': 'PA',
#    'storeUrl': 'http://www.mcpennsylvania.com/4353',
#    'playplace': 'Y',
#    'address': '561 N MAIN ST',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.128715, 40.175038]},
#   'type': 'Feature',
#   'properties': {'city': 'HORSHAM',
#    'zip': '19044',
#    'freeWifi': 'Y',
#    'storeNumber': '3507',
#    'phone': '(215)443-7745',
#    'state': 'PA',
#    'storeUrl': 'http://www.mcpennsylvania.com/3507',
#    'playplace': 'N',
#    'address': 'PA RTE 611 AND PINE AVE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.308881, 40.3163]},
#   'type': 'Feature',
#   'properties': {'city': 'SOUDERTON',
#    'zip': '18964',
#    'freeWifi': 'Y',
#    'storeNumber': '4134',
#    'phone': '(215)723-0193',
#    'state': 'PA',
#    'storeUrl': 'http://www.mcpennsylvania.com/4134',
#    'playplace': 'Y',
#    'address': '727 RT 113',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  {'geometry': {'type': 'Point', 'coordinates': [-75.265629, 40.288169]},
#   'type': 'Feature',
#   'properties': {'city': 'HATFIELD',
#    'zip': '19440',
#    'freeWifi': 'Y',
#    'storeNumber': '16575',
#    'phone': '(215)997-8944',
#    'state': 'PA',
#    'storeUrl': 'http://www.mcpennsylvania.com/16575',
#    'playplace': 'N',
#    'address': '1611 BETHELEHEM PIKE',
#    'storeType': 'FREESTANDING',
#    'archCard': 'Y',
#    'driveThru': 'Y'}},
#  ...]

# %%
# with open('data/mcdonalds.json') as f:
#     mcd = json.load(f)


out = len([branch for branch in mcd['features'] if branch['properties']['freeWifi'] == 'N'])
out
stores = mcd['features']

numbers = [int(store['properties']['storeNumber']) for store in stores]
#print(min(numbers), max(numbers))

storeTypes = [store['properties']['storeType'] for store in stores]
len(set(storeTypes))

states = [store['properties']['state'] for store in stores]

states = {}
for store in stores:
    state = store['properties']['state']
    if states.get(state) == None:
        states[state] = 0
    states[state] += 1
states

#print(sorted(list(states.items()), key=lambda x: x[1]))


out = len([branch for branch in mcd['features'] if branch['properties']['freeWifi'] == 'Y' and branch['properties']['state'] == 'NY'])
out
# Out:
# 630

# %% [markdown]
# The file mcdonalds.json contains basic information about all the McDonald’s stores in the USA. Use the _re_ module to parse the file and answer the following questions.
#
# * Part 1 - How many McDonald’s stores are there in the USA?
# * Part 2 - How many McDonald’s stores do not have free WiFi?
# * Part 3 - What is the minimal and maximal “store number”?
# * Part 4 - How many different “store types” are there?
# * Part 5 - What is the state with the highest number of McDonald’s stores?
# * Part 6 - How many stores are there in New York state and have free WiFi?

# %% [markdown]
# ### Solution

# %%
f_path = "mcdonalds.json"
with open(f_path) as f:
    mcd = json.load(f)

# %% [markdown]
# #### Part 1

# %%
stores = mcd['features']
print(len(stores))

# %% [markdown]
# #### Part 2

# %%
print(len([store for store in stores if store['properties']['freeWifi'] == 'N']))

# %% [markdown]
# #### Part 3

# %%
numbers = [int(store['properties']['storeNumber']) for store in stores]
print(min(numbers), max(numbers))

# %% [markdown]
# #### Part 4

# %%
types = set([store['properties']['storeType'] for store in stores])
print(types)

# %% [markdown]
# #### Part 5

# %%
# List all states
states = set([store['properties']['state'] for store in stores])

# Initiate a dictionary for the information
mcd_per_state = {}
for state in states:
    mcd_per_state[state] = 0

# Count the stores for each state
for store in stores:
    mcd_per_state[store['properties']['state']] += 1

# Answer the question
print(sorted(list(mcd_per_state.items()), key=lambda x: x[1]))

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# Jupyter notebooks are actually JSON-formatted files. Read the notebook (a little bit recursive, but don't worry...), explore its structure and use the `json` module to create its table of content.

# %%
with open('the_json_format.ipynb') as f:
    notebook = json.load(f)

# %% [markdown]
# ### Solution

# %%
table_of_content = []
for cell in notebook['cells']:
    if cell['cell_type'] == 'markdown':
        text = cell['source'][0]
        if text.startswith('#'):
            table_of_content.append(text)
print(table_of_content)

# %%
table_of_content = '\n'.join(map(lambda s: s[1:].replace('#', '\t'), table_of_content))
print(table_of_content)

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# > **Credit:** Many thanks to **Itay Margolin** for this nice exercise

# %% [markdown]
# You are two friends located at two locations in the US, and in this exercise we will write a utility to help you find a meeting location, and it's going to be a McDonald's store.
#
# Follow the following steps:
# * Step 1 - Write the `haversine(pt1, pt2)` function to calculate the [Haversine distance](https://en.wikipedia.org/wiki/Haversine_formula) between `pt1` and `pt2`. The points should be 2-tuples with longitude and latitude (in this order).
#
# * Step 2 - Implement a script that asks the users for their (Boolean) preferences (`playground` and `WiFi`), loads the data from mcdonalds.json (available [here](https://drive.google.com/drive/folders/1KQXg5CpZ8u59ybkvOnFPzo_WaLHxek_g?usp=sharing)) and filters the possible locations.
#
# * Step 3 - Implement a script that asks the users for their locations and finds the McDonald's store which satisfy the preferences and is the nearest to the middle of their locations.

# %% [markdown]
# ### Solution

# %% [markdown]
# #### Step 1

# %%
from math import sin, cos, sqrt, atan2, radians

def haversine_distance(pt1, pt2):

    # approximate radius of earth in km
    R = 6373.0
    
    lon1, lat1 = radians(pt1[0]), radians(pt1[1])
    lon2, lat2 = radians(pt2[0]), radians(pt2[1])
    
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    
    a = sin(dlat / 2.0)**2.0 + cos(lat1) * cos(lat2) * sin(dlon / 2.0)**2.0
    
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R*c

# %% [markdown]
# #### Step 2

# %%
is_playplace =   input("is playplace (Y/N/?):")
isWifi =         input("isWifi (Y/N/?):")
# Out:
# is playplace (Y/N/?):Y
# isWifi (Y/N/?):Y

# %%
filename = 'mcdonalds.json'

# %%
import json
with open(filename) as f:
    mcd = json.load(f)["features"]

# %%
mcd = [store for store in mcd if store["properties"]["freeWifi"]==isWifi]

# %%
mcd = [store for store in mcd if store["properties"]["playplace"]==is_playplace]

# %%
mcd[0]
# Out:
# {'geometry': {'coordinates': [-80.218683, 25.765501], 'type': 'Point'},
#  'properties': {'address': '1400 SW 8TH ST',
#   'archCard': 'Y',
#   'city': 'MIAMI',
#   'driveThru': 'Y',
#   'freeWifi': 'Y',
#   'phone': '(305)285-0974',
#   'playplace': 'Y',
#   'state': 'FL',
#   'storeNumber': '7408',
#   'storeType': 'FREESTANDING',
#   'storeUrl': 'http://www.mcflorida.com/7408',
#   'zip': '33135'},
#  'type': 'Feature'}

# %% [markdown]
# #### Part 3

# %%
user_first_lon = float(input("User A lon:"))
user_first_lat = float(input("User A lat:"))
user_sec_lon =   float(input("User B lon:"))
user_sec_lat =   float(input("User B lat:"))
# Out:
# User A lon:-80
# User A lat:30
# User B lon:-85
# User B lat:40

# %%
middle_spot = ((user_first_lat + user_sec_lat) / 2 , (user_first_lon + user_sec_lon) / 2)

# %%
def d_from_midpoint(store):
    pt1 = middle_spot
    pt2 = store["geometry"]["coordinates"][::-1]
    return haversine_distance(pt1, pt2)

# %%
sorted(mcd, key=d_from_midpoint)[0]
# Out:
# {'geometry': {'coordinates': [-82.480815, 34.787288], 'type': 'Point'},
#  'properties': {'address': '3435 HIGHWAY 153',
#   'archCard': 'Y',
#   'city': 'PIEDMONT',
#   'driveThru': 'Y',
#   'freeWifi': 'Y',
#   'phone': '(864)295-9095',
#   'playplace': 'Y',
#   'state': 'SC',
#   'storeNumber': '22083',
#   'storeType': 'FREESTANDING',
#   'storeUrl': 'http://www.mcsouthcarolina.com/22083',
#   'zip': '29673'},
#  'type': 'Feature'}
